# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def data_clean(link,skip_rows):
    
    df=pd.read_csv(link,skiprows=skip_rows)
    #df=pd.read_json(link)
    #df=pd.read_excel(link)
    #df=pd.read_html(link)
    df.dropna(how='all',inplace=True)
    df.drop_duplicates(inplace=True)
    return df

# %%
df=data_clean(r"C:\Users\Osamah\code python\Data Analysis\My_Orders.csv",0)

# %%
#for see all the data and some fun
df.describe()
# Out:
#            Order ID           Lat           Lng  Phone Number      Quantity  \
# count  20000.000000  20000.000000  20000.000000  2.000000e+04  20000.000000
# mean   10000.500000     30.461665     11.339318  5.498561e+09      1.936750
# std     5773.647028      8.126746     53.194139  2.889298e+08      2.288736
# min        1.000000     18.231100   -115.149200  5.000075e+09      1.000000
# 25%     5000.750000     24.453900      2.352200  5.248352e+09      1.000000
# 50%    10000.500000     27.180900     37.134300  5.498545e+09      1.000000
# 75%    15000.250000     36.202100     42.500400  5.749508e+09      2.000000
# max    20000.000000     48.856600     56.324200  5.999985e+09     13.000000
#
#          Unit Price      Discount   Total price          Cost
# count  20000.000000  20000.000000  20000.000000  20000.000000
# mean     609.292000     61.448600   1181.035250   1119.586650
# std      617.976051    142.181639   2272.317786   2155.054747
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order ID              20000 non-null  float64
#  1   Order Date            20000 non-null  object
#  2   Country               20000 non-null  object
#  3   City                  20000 non-null  object
#  4   Branch                20000 non-null  object
#  5   Branch Name           20000 non-null  object
#  6   Lat                   20000 non-null  float64
#  7   Lng                   20000 non-null  float64
#  8   Customer First Name   20000 non-null  object
#  9   Customer Last Name    20000 non-null  object
#  10  Customer full Name    20000 non-null  object
#  11  Email                 20000 non-null  object
#  12  Phone Number          20000 non-null  int64
#  13  Category              20000 non-null  object
#  14  Sub Category          20000 non-null  object
# ...

# %%
city_Qu_Total=df.groupby(['City'])['Quantity'].sum()
city_Qu_Total
# Out:
# City
# Abu Dhabi     4555.0
# Aleppo        2138.0
# Aseer         1653.0
# Asyut         2004.0
# Cairo         2653.0
# Casablanca    1179.0
# Damascus      1300.0
# Dammam         985.0
# Dubai          840.0
# Fujairah       254.0
# Homs          1525.0
# Jeddah        6167.0
# Las Vegas     2505.0
# New York      4209.0
# Paris         2201.0
# Riyadh        2989.0
# Washington    1578.0
# Name: Quantity, dtype: float64

# %%
cat_Qu_Total=df.groupby('Category')['Quantity'].sum()
cat_Qu_Total
# Out:
# Category
# Digital Camera     3629.0
# Fitness Tracker    3731.0
# Gaming Console     3815.0
# Headphones         3797.0
# Laptop             4484.0
# Smart Speaker      3687.0
# Smartphone         4003.0
# Smartwatch         3594.0
# Tablet             4169.0
# VR Headset         3826.0
# Name: Quantity, dtype: float64

# %%
status=df['Status'].value_counts()
status
# Out:
# Status
# True     14013
# False     5987
# Name: count, dtype: int64

# %%
df
# Out:
#        Order ID Order Date               Country        City Branch  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03
# 3           4.0   1/1/2023  United Arab Emirates   Abu Dhabi   AD01
# 4           5.0   1/1/2023                   USA  Washington   WH01
# ...         ...        ...                   ...         ...    ...
# 19995   19996.0   1/9/2023               Morocco  Casablanca   CS01
# 19996   19997.0   1/9/2023                 Syria        Homs   HS01
# 19997   19998.0   1/9/2023                   USA   Las Vegas   LV01
# 19998   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03
# 19999   20000.0   1/9/2023                   USA  Washington   WH01
#
#       Branch Name      Lat       Lng Customer First Name Customer Last Name  \
# ...

# %%
#bins that the number for item to see and the number in x in the plot for the how manu the quan have and the y for how manu theis number duplicat 
sns.histplot(df['Quantity'],bins=5)
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.barplot(x='Category',y='Unit Price',data=df,palette='crest')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Osamah\AppData\Local\Temp\ipykernel_19540\2954594229.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category',y='Unit Price',data=df,palette='crest')

# %%
pl=sns.scatterplot(x='Discount',y='Cost',data=df,size='Quantity',hue='Category',palette='crest')
pl.legend(bbox_to_anchor=(1,1),loc='upper left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order ID              20000 non-null  float64
#  1   Order Date            20000 non-null  object
#  2   Country               20000 non-null  object
#  3   City                  20000 non-null  object
#  4   Branch                20000 non-null  object
#  5   Branch Name           20000 non-null  object
#  6   Lat                   20000 non-null  float64
#  7   Lng                   20000 non-null  float64
#  8   Customer First Name   20000 non-null  object
#  9   Customer Last Name    20000 non-null  object
#  10  Customer full Name    20000 non-null  object
#  11  Email                 20000 non-null  object
#  12  Phone Number          20000 non-null  int64
#  13  Category              20000 non-null  object
#  14  Sub Category          20000 non-null  object
# ...

# %%
mydata=df.groupby(['Category','Sub Category','Item'],as_index=False)[['Quantity','Cost','Discount']].sum()
mydata
# Out:
#            Category        Sub Category                   Item  Quantity  \
# 0    Digital Camera           Canon EOS  Canon EOS M50 Mark II     283.0
# 1    Digital Camera           Canon EOS           Canon EOS R6     148.0
# 2    Digital Camera  Canon EOS R Series            Canon EOS R     251.0
# 3    Digital Camera  Canon EOS R Series           Canon EOS R5     181.0
# 4    Digital Camera   Fujifilm X Series          Fujifilm X-T4     214.0
# ..              ...                 ...                    ...       ...
# 210      VR Headset        Pimax Vision       Pimax Vision 8KX     182.0
# 211      VR Headset     Samsung Odyssey     Samsung Odyssey G9     229.0
# 212      VR Headset    Sony PlayStation         PlayStation VR     177.0
# 213      VR Headset         Valve Index     Valve Index VR Kit     203.0
# 214      VR Headset         Valve Index   Valve Index VR Kit 2     198.0
#
#          Cost  Discount
# 0    174938.0    8729.0
# 1    349953.0   19899.0
# ...

# %%
sns.pairplot(mydata)
