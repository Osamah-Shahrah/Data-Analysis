# %%
import pandas as pd

# %%
df1=pd.read_html("https://www.worldometers.info/world-population/population-by-country/")
# Out:
# [       # Country (or dependency)  Population  (2024) Yearly  Change  \
#  0      1                   India          1450935791         0.89 %
#  1      2                   China          1419321278        -0.23 %
#  2      3           United States           345426571         0.57 %
#  3      4               Indonesia           283487931         0.82 %
#  4      5                Pakistan           251269164         1.52 %
#  ..   ...                     ...                 ...            ...
#  229  230              Montserrat                4389        -0.70 %
#  230  231        Falkland Islands                3470        -0.20 %
#  231  232                 Tokelau                2506         4.55 %
#  232  233                    Niue                1819         0.11 %
#  233  234                Holy See                 496         0.00 %
#
#       Net  Change  Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  \
# ...

# %%
df=pd.read_csv(r'C:\Users\Osamah\code python\Data Analysis\Orders.csv')
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        homs   hs01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      riyadh   rd01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      riyadh   rd03  24.7743
# 3           NaN        NaN                   NaN         NaN    NaN      NaN
# 4           4.0   1/1/2023  United Arab Emirates   abu dhabi   ad01  24.4539
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  washington   wh01  38.9072
#
# ...

# %%
#frist row
df.head(5)
# Out:
#    Order ID Order Date               Country       City Branch      Lat  \
# 0       1.0   1/1/2023                 Syria       homs   hs01  34.7326
# 1       2.0   1/1/2023          Saudi Arabia     riyadh   rd01  24.7136
# 2       3.0   1/1/2023          Saudi Arabia     riyadh   rd03  24.7743
# 3       NaN        NaN                   NaN        NaN    NaN      NaN
# 4       4.0   1/1/2023  United Arab Emirates  abu dhabi   ad01  24.4539
#
#        Lng Customer First Name Customer Last Name                    Email  \
# 0  36.7136                lina          alrrashid  LINA.ALRRASHID@MAIL.COM
# 1  46.6753                omar              eurul      OMAR.EURUL@MAIL.COM
# 2  46.7386                iman           iismaeil   IMAN.IISMAEIL@MAIL.COM
# 3      NaN                 NaN                NaN                      NaN
# 4  54.3773               ahmad              rihan     AHMAD.RIHAN@MAIL.COM
#
#       Phone Number        Category        Sub Category                   Item  \
# ...

# %%
#last row
df.tail(5)
# Out:
#        Order ID Order Date       Country        City Branch      Lat  \
# 19999   19996.0   1/9/2023       Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023         Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023           USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023  Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023           USA  washington   wh01  38.9072
#
#             Lng Customer First Name Customer Last Name  \
# 19999    7.5898               ahmad                iad
# 20000   36.7136                 ali              kiali
# 20001 -115.1398              husayn             salayk
# 20002   39.1925               fatin            bahriin
# 20003  -77.0369               ahmad             shakur
#
#                         Email     Phone Number        Category  \
# 19999      AHMAD.IAD@MAIL.COM  Tel: 5880578642  Gaming Console
# 20000      Ali.kiali@mail.com  Tel: 5286384144      Smartwatch
# ...

# %%
df1=df[['Country','City','Category']]
df1
# Out:
#                     Country        City        Category
# 0                     Syria        homs          Tablet
# 1              Saudi Arabia      riyadh      Smartphone
# 2              Saudi Arabia      riyadh  Digital Camera
# 3                       NaN         NaN             NaN
# 4      United Arab Emirates   abu dhabi          Tablet
# ...                     ...         ...             ...
# 19999               Morocco  casablanca  Gaming Console
# 20000                 Syria        homs      Smartwatch
# 20001                   USA   las vegas  Gaming Console
# 20002          Saudi Arabia      jeddah      Headphones
# 20003                   USA  washington      Smartwatch
#
# [20004 rows x 3 columns]

# %%
df.describe()
# Out:
#            Order ID           Lat           Lng      Quantity    Unit Price  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean   10000.500000     30.461665     11.339318      1.936750    609.292000
# std     5773.647028      8.126746     53.194139      2.288736    617.976051
# min        1.000000     18.231100   -115.149200      1.000000     29.000000
# 25%     5000.750000     24.453900      2.352200      1.000000    179.000000
# 50%    10000.500000     27.180900     37.134300      1.000000    399.000000
# 75%    15000.250000     36.202100     42.500400      2.000000    899.000000
# max    20000.000000     48.856600     56.324200     13.000000   3999.000000
#
#            Discount
# count  18889.000000
# mean      65.021528
# std      145.481646
# min        0.290000
# 25%        9.800000
# 50%       23.980000
# 75%       64.900000
# max     3999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20004 entries, 0 to 20003
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order ID             20000 non-null  float64
#  1   Order Date           20000 non-null  object
#  2   Country              20000 non-null  object
#  3   City                 20000 non-null  object
#  4   Branch               20000 non-null  object
#  5   Lat                  20000 non-null  float64
#  6   Lng                  20000 non-null  float64
#  7   Customer First Name  20000 non-null  object
#  8   Customer Last Name   20000 non-null  object
#  9   Email                20000 non-null  object
#  10  Phone Number         20000 non-null  object
#  11  Category             20000 non-null  object
#  12  Sub Category         20000 non-null  object
#  13  Item                 20000 non-null  object
#  14  SalesPerson ID       20000 non-null  object
# ...

# %%
df['Country'].describe()
# Out:
# count            20000
# unique               7
# top       Saudi Arabia
# freq              6077
# Name: Country, dtype: object

# %%
df[['Country','City','Category']].describe()
# Out:
#              Country    City Category
# count          20000   20000    20000
# unique             7      17       10
# top     Saudi Arabia  jeddah   Laptop
# freq            6077    3186     2173

# %%
#use shift+tab to show items for the function
df1.count()
# Out:
# Country     20000
# City        20000
# Category    20000
# dtype: int64

# %%
df2=df[['Country','Order Date','Order ID','Quantity','Unit Price']]
df2
# Out:
#                     Country  Order ID  Quantity  Unit Price
# 0                     Syria       1.0       1.0       999.0
# 1              Saudi Arabia       2.0       1.0      1199.0
# 2              Saudi Arabia       3.0       1.0      1299.0
# 3                       NaN       NaN       NaN         NaN
# 4      United Arab Emirates       4.0       2.0       199.0
# ...                     ...       ...       ...         ...
# 19999               Morocco   19996.0       1.0       399.0
# 20000                 Syria   19997.0       2.0       299.0
# 20001                   USA   19998.0       1.0        99.0
# 20002          Saudi Arabia   19999.0       1.0        99.0
# 20003                   USA   20000.0       1.0       249.0
#
# [20004 rows x 4 columns]

# %%
df2['Unit Price'].sum()
# Out:
# 12185840.0

# %%
df2[['Unit Price','Quantity']].agg(['count','sum','mean'])
# Out:
#          Unit Price     Quantity
# count  2.000000e+04  20000.00000
# sum    1.218584e+07  38735.00000
# mean   6.092920e+02      1.93675

# %%
df2.groupby('Country').sum()
# Out:
#                         Order ID  Quantity  Unit Price
# Country
# Egypt                 24668954.0    4657.0   1522264.0
# France                11354058.0    2201.0    672175.0
# Morocco                6020059.0    1179.0    373873.0
# Saudi Arabia          60646871.0   11794.0   3746903.0
# Syria                 26487682.0    4963.0   1542099.0
# USA                   42185810.0    8292.0   2600834.0
# United Arab Emirates  28646566.0    5649.0   1727692.0

# %%
df2.groupby(['Country','City']).sum()
# Out:
#                                    Order ID  \
# Country              City
# Egypt                asyut       10565438.0
#                      cairo       14103516.0
# France               paris       11354058.0
# Morocco              casablanca   6020059.0
# Saudi Arabia         aseer        8450209.0
#                      dammam       5111361.0
#                      jeddah      31639689.0
#                      riyadh      15445612.0
# Syria                aleppo      11899180.0
#                      damascus     6800343.0
#                      homs         7788159.0
# USA                  las vegas   13072221.0
#                      new york    20883667.0
#                      washington   8229922.0
# United Arab Emirates abu dhabi   22785092.0
#                      dubai        4572982.0
#                      fujairah     1288492.0
#
#                                                                         Order Date  \
# Country              City
# ...

# %%
df1.groupby(['Country','City']).agg(['sum','count'])
# Out:
#                                                                           Category  \
#                                                                                sum
# Country              City
# Egypt                asyut       TabletHeadphonesDigital CameraDigital CameraFi...
#                      cairo       HeadphonesLaptopTabletTabletSmartphoneSmart Sp...
# France               paris       HeadphonesSmartphoneFitness TrackerSmartwatchS...
# Morocco              casablanca  SmartwatchVR HeadsetFitness TrackerSmartphoneL...
# Saudi Arabia         aseer       LaptopDigital CameraFitness TrackerTabletGamin...
#                      dammam      VR HeadsetDigital CameraSmartphoneGaming Conso...
#                      jeddah      TabletSmartwatchTabletLaptopLaptopFitness Trac...
#                      riyadh      SmartphoneDigital CameraDigital CameraVR Heads...
# Syria                aleppo      SmartwatchDigital CameraSmartwatchSmartwatchLa...
# ...

# %%
df['Unit Price'].mean()
# Out:
# 609.292

# %%
df_groupby=df[['Country','City','Quantity']].groupby(['Country','City']).agg(['sum','mean'])
df_groupby
# Out:
#                                 Quantity
#                                      sum      mean
# Country              City
# Egypt                asyut        2004.0  1.879925
#                      cairo        2653.0  1.881560
# France               paris        2201.0  1.956444
# Morocco              casablanca   1179.0  1.942339
# Saudi Arabia         aseer        1653.0  1.922093
#                      dammam        985.0  2.006110
#                      jeddah       6167.0  1.935656
#                      riyadh       2989.0  1.940909
# Syria                aleppo       2138.0  1.847882
#                      damascus     1300.0  1.884058
#                      homs         1525.0  1.945153
# USA                  las vegas    2505.0  1.935858
#                      new york     4209.0  2.006196
#                      washington   1578.0  1.892086
# United Arab Emirates abu dhabi    4555.0  2.005724
#                      dubai         840.0  1.862528
# ...

# %%
df_groupby.plot()
# Out:
# <Axes: xlabel='Country,City'>

# %%
df_groupby.plot(kind='bar',y=('Quantity','sum'),title="chart for country")
# Out:
# <Axes: title={'center': 'chart for country'}, xlabel='Country,City'>
